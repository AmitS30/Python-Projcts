# %%
import requests

# %%
import bs4
from bs4 import BeautifulSoup

# %%
url='https://www.cricbuzz.com/cricket-series/ipl-2020/auction/completed'

# %%
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'\r\n\r\n<!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"><head><meta charset="utf-8"><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);\tif(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}\tbody, .cb-comm-pg, .cb-hm-mid {min-height:1000px}\t.container{width:980px;margin:0 auto;}\t.page{max-width: 980px;margin: 0 auto;position: relative;}\t.cb-col-8 {width:8%;}\t.cb-col-10 {width:10%;}\t.cb-col-14 {width:14%;}\t.cb-col-16 {width:16%;}\t.cb-col-20 {width:20%;}\t.cb-col-25 {width:25%;}\t.cb-col-27 {width:27%;}\t.cb-col-30 {width:30%;}\t.cb-col-33 {width:33%;}\t.cb-col-40 {width:40%;}\t.cb-col-46 {width:46%;}\t.cb-col-47 {width:47%;}\t.cb-col-50 {width:50%;}\t.cb-col-60 {width:60%;}\t.cb-c
# ...

# %%
soup=BeautifulSoup(page.content)

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
a=soup.find('title')
a
# Out:
# <title itemprop="name">IPL Auction 2020 - Completed auctions | Cricbuzz.com</title>

# %%
a.text
# Out:
# 'IPL Auction 2020 - Completed auctions | Cricbuzz.com'

# %%
Name= [i.text for i in soup.findAll('div',{'class':'cb-font-18'})]

# %%
Name
# Out:
# [' Vinay Kumar ',
#  ' Kesrick Williams ',
#  ' Isuru Udana ',
#  ' Tom Curran ',
#  ' Nikhil Naik ',
#  ' Shahbaz Ahmed ',
#  ' Lalit Yadav ',
#  ' Andrew Tye ',
#  ' Dale Steyn ',
#  ' Mark Wood ',
#  ' Marcus Stoinis ',
#  ' Colin Munro ',
#  ' Ben Cutting ',
#  ' Ravisrinivasan Sai Kishore ',
#  ' Tushar Deshpande ',
#  ' Simran Singh ',
#  ' Srikar Bharat ',
#  ' Daniel Sams ',
#  ' Shahrukh Khan ',
#  ' Pavan Deshpande ',
#  ' Rohan Kadam ',
#  ' Mohit Sharma ',
#  ' Kusal Perera ',
#  ' Colin de Grandhomme ',
#  ' Sanjay Yadav ',
#  ' Prince Balwant Rai ',
#  ' Digvijay Deshmukh ',
#  ' Aniruddha Joshi ',
#  ' Saurabh Dubey ',
#  ' Vaibhav Arora ',
#  ' George Garton ',
#  ' Nathan Ellis ',
#  ' Abdul Samad ',
#  ' Sujit Nayak ',
#  ' Tajinder Singh ',
#  ' Yudhvir Singh ',
#  ' Liam Plunkett ',
#  ' James Pattinson ',
#  ' Pravin Tambe ',
#  ' Kuldeep Sen ',
#  ' Aryan Juyal ',
#  ' Sumit Kumar ',
#  ' Oshane Thomas ',
#  ' Kane Richardson ',
#  ' Matt Henry ',
# ...

# %%
Sold_Unsold= [i.text for i in soup.findAll('div',{'class':'cb-col cb-col-20 cb-lst-itm-sm'})]
Sold_Unsold
# Out:
# [' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
#  ' SOLD ',
#  ' UNSOLD ',
#  ' UNSOLD ',
# ...

# %%
Base_Price= [i.text for i in soup.findAll('div',{'class':'cb-col cb-col-33 cb-lst-itm-sm text-left','class':'cb-font-16'})]
Base_Price
# Out:
# ['1.00\xa0\xa0Crore',
#  '-',
#  '',
#  '50.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '50.00\xa0\xa0Lakh',
#  '50.00\xa0\xa0Lakh',
#  'RCB',
#  '1.00\xa0\xa0Crore',
#  '1.00\xa0\xa0Crore',
#  'RR',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'KKR',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'RCB',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'DC',
#  '1.00\xa0\xa0Crore',
#  '1.00\xa0\xa0Crore',
#  'RR',
#  '2.00\xa0\xa0Crore',
#  '2.00\xa0\xa0Crore',
#  'RCB',
#  '50.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '1.00\xa0\xa0Crore',
#  '4.80\xa0\xa0Crore',
#  'DC',
#  '1.00\xa0\xa0Crore',
#  '-',
#  '',
#  '75.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'CSK',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'DC',
#  '20.00\xa0\xa0Lakh',
#  '55.00\xa0\xa0Lakh',
#  'PBKS',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
# ...

# %%
Base_Price=Base_Price[0:len(Base_Price)-3:3]
Base_Price=[i.replace('\xa0\xa0',' ') for i in Base_Price]

# %%
Final_Price=[i.text for i in soup.find_all('div',{'class':'cb-col cb-col-33 cb-lst-itm-sm text-left','class':'cb-font-16'})]

# %%
Final_Price
# Out:
# ['1.00\xa0\xa0Crore',
#  '-',
#  '',
#  '50.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '50.00\xa0\xa0Lakh',
#  '50.00\xa0\xa0Lakh',
#  'RCB',
#  '1.00\xa0\xa0Crore',
#  '1.00\xa0\xa0Crore',
#  'RR',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'KKR',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'RCB',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'DC',
#  '1.00\xa0\xa0Crore',
#  '1.00\xa0\xa0Crore',
#  'RR',
#  '2.00\xa0\xa0Crore',
#  '2.00\xa0\xa0Crore',
#  'RCB',
#  '50.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '1.00\xa0\xa0Crore',
#  '4.80\xa0\xa0Crore',
#  'DC',
#  '1.00\xa0\xa0Crore',
#  '-',
#  '',
#  '75.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'CSK',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'DC',
#  '20.00\xa0\xa0Lakh',
#  '55.00\xa0\xa0Lakh',
#  'PBKS',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
# ...

# %%
Final_Price=Final_Price[1:len(Final_Price)-3:3]
Final_Price=[i.replace('\xa0\xa0',' ') for i in Final_Price]

# %%
Sold_To=[i.text for i in soup.find_all('div',{'class':'cb-col cb-col-33 cb-lst-itm-sm text-left','class':'cb-font-16'})]

# %%
Sold_To
# Out:
# ['1.00\xa0\xa0Crore',
#  '-',
#  '',
#  '50.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '50.00\xa0\xa0Lakh',
#  '50.00\xa0\xa0Lakh',
#  'RCB',
#  '1.00\xa0\xa0Crore',
#  '1.00\xa0\xa0Crore',
#  'RR',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'KKR',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'RCB',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'DC',
#  '1.00\xa0\xa0Crore',
#  '1.00\xa0\xa0Crore',
#  'RR',
#  '2.00\xa0\xa0Crore',
#  '2.00\xa0\xa0Crore',
#  'RCB',
#  '50.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '1.00\xa0\xa0Crore',
#  '4.80\xa0\xa0Crore',
#  'DC',
#  '1.00\xa0\xa0Crore',
#  '-',
#  '',
#  '75.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'CSK',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
#  'DC',
#  '20.00\xa0\xa0Lakh',
#  '55.00\xa0\xa0Lakh',
#  'PBKS',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '-',
#  '',
#  '20.00\xa0\xa0Lakh',
#  '20.00\xa0\xa0Lakh',
# ...

# %%
Sold_To=Sold_To[2:len(Sold_To)-3:3]
Sold_To=[i.replace('\xa0\xa0',' ') for i in Sold_To]

# %%
Role= [i.text for i in soup.findAll('div',{'class':'cb-col cb-col-80','class':'cb-font-12 text-gray'})]

# %%
Role
# Out:
# [' Bowler • India ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Bowler • West Indies ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Bowling Allrounder • Sri Lanka ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Bowling Allrounder • England ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Batsman • India ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' WK-Batsman • India ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Batting Allrounder • India ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Bowler • Australia ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Bowler • South Africa ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Bowler • England ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Batting Allrounder • Australia ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
#  ' Batting Allrounder • New Zealand ',
#  'Base Price',
#  'Final Price',
#  'Sold To',
# ...

# %%
Role=Role[0::4]
Role=[i.split(' • ')[0] for i in Role]

# %%
import pandas as pd

# %%
Table=pd.DataFrame({
    "Name":Name,
    "Role": Role,
    "Status":Sold_Unsold,
    "Base Price": Base_Price,
    "Final Price": Final_Price,
    "Team": Sold_To })

# %%
df=pd.DataFrame(Table)

# %%
df
# Out:
#                     Name                 Role    Status  Base Price  \
# 0           Vinay Kumar                Bowler   UNSOLD   1.00 Crore
# 1      Kesrick Williams                Bowler   UNSOLD   50.00 Lakh
# 2           Isuru Udana    Bowling Allrounder     SOLD   50.00 Lakh
# 3            Tom Curran    Bowling Allrounder     SOLD   1.00 Crore
# 4           Nikhil Naik               Batsman     SOLD   20.00 Lakh
# ..                   ...                  ...       ...         ...
# 121   Cheteshwar Pujara               Batsman   UNSOLD   50.00 Lakh
# 122       Hanuma Vihari    Batting Allrounder   UNSOLD   50.00 Lakh
# 123       Robin Uthappa            WK-Batsman     SOLD   1.50 Crore
# 124         Eoin Morgan               Batsman     SOLD   1.50 Crore
# 125          Chris Lynn               Batsman     SOLD   2.00 Crore
#
#     Final Price Team
# 0             -
# 1             -
# 2    50.00 Lakh  RCB
# 3    1.00 Crore   RR
# 4    20.00 Lakh  KKR
# ..          ...  ...
# ...

# %%
Table.head(10)
# Out:
#                  Name                 Role    Status  Base Price Final Price  \
# 0        Vinay Kumar                Bowler   UNSOLD   1.00 Crore           -
# 1   Kesrick Williams                Bowler   UNSOLD   50.00 Lakh           -
# 2        Isuru Udana    Bowling Allrounder     SOLD   50.00 Lakh  50.00 Lakh
# 3         Tom Curran    Bowling Allrounder     SOLD   1.00 Crore  1.00 Crore
# 4        Nikhil Naik               Batsman     SOLD   20.00 Lakh  20.00 Lakh
# 5      Shahbaz Ahmed            WK-Batsman     SOLD   20.00 Lakh  20.00 Lakh
# 6        Lalit Yadav    Batting Allrounder     SOLD   20.00 Lakh  20.00 Lakh
# 7         Andrew Tye                Bowler     SOLD   1.00 Crore  1.00 Crore
# 8         Dale Steyn                Bowler     SOLD   2.00 Crore  2.00 Crore
# 9          Mark Wood                Bowler   UNSOLD   50.00 Lakh           -
#
#   Team
# 0
# 1
# 2  RCB
# 3   RR
# 4  KKR
# 5  RCB
# 6   DC
# 7   RR
# 8  RCB
# 9

# %%
df.to_csv('Table.csv',index=False)

# %%
Table=pd.read_csv('Table.csv')
