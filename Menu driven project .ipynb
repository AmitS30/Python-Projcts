# %%
print("Enter 1 for doing operation on the list ")
print("Enter 2 for doing operation on the set ")
print("Enter 3 for doing operation on the dictionary ")
print("Enter 4 for doing operation on the tuple") 

print("-"*100)

ch=int(input("Enter your choice "))
print("-"*100)

if ch==1:
    print("-"*100)
    print("Your choice is list")
    print("-"*100)
    print("Create a list")
    print("-"*100)
    l1=list(eval(input("Enter values in list: ")))
    
    
    print("-"*100)
    print("Enter 1 for Addion operation")
    print("Enter 2 for Deletion")
    print("Enter 3 for Information about the List")
    print("-"*100)
    ch1=int(input("Enter your choice of operation to do on list"))
    print("-"*100)
    
    
    if ch1==1:
        
        print("You have chose Addion operation to perform on list")
        
        print("-"*100)
        
        print("Enter 1 to perform Append operarion on list")
        print("Enter 2 to perform Insert operation on list")
        print("Enter 3 to perform Extend operation on list")
        print("-"*100)
        ch2=int(input("Choose the operation to do on list: "))
        if ch2==1:
            print("You chose Append operarion")
            print("In append single values get added to at the last of the list")
            l2=eval(input("Enter value to append in your list: "))
            l1.append(l2)
            print("Your outcome is",l1)
        elif ch2==2:
            print("You chose Insert operation")
            print("In Insert we can add single values at any position we want.")
            
            l2=eval(input("Enter the value"))
            a=int(input("Enter the position index"))
            l1.insert(a,l2)
            print("Your outcome is",l1)
        elif ch2==3:
            print("You chose Extend operator")
            print("In Extend operator multiple values get added at the end of the list")
            l2=eval(input("Enter the values to be extended in your list: "))
            l1.extend(l2)
            print("-"*100)
            print("The final outcome is:",l1)
            print("-"*100)
        else:
            print("Invalid choice")
    elif ch1==2:
       
        print("You have chosse Deletion operation")
        print("-"*100)    
        print("Enter 1 to perform Pop operation")
        print("Enter 2 to perform Remove operation")
        print("Enter 3 to perform Clear operation")
        print("Enter 4 to perform Delete operation")
        print("-"*100)
        ch3=int(input("Enter your choice"))
        if ch3==1:
            print("You chose Pop operation")
            print("In pop operation you can remove values on the basis of indexing or the position of the value")
            a=int(input("Enter the position of the value"))
            l1.pop(a)
            print("The final outcome is",l1)
        elif ch3==2:
            print("You chose Remove operation")
            print("In remove operation you can remove the value directly")
            a=int(input("Enter the value you want to remove"))
            l1.remove(a)
            print("The outcome of the is",l1)
        elif ch3==3:
            print("You chose Remove operation")
            print("This will clear all values of the list")
            l1.clear()
            print("The outcome will show empty list",l1)
        elif ch3==4:
            print("You chose Delete operation")
            print("This will delete the list")
            del l1
            print("You have successfully deleted the list")
        else:
            print("Invalid choice")
    elif ch1==3:
        print("The list is ordered heterogeous elements which are mutable")
    else:
        print("Invalid choice")
#set 

elif ch==2:
        print("-"*100)
        print("You have chose Set dataype")
        print("-"*100)
        print("Create a Set")
            
        s1=set(eval(input("Enter the values")))
        print("Enter 1 to perform Additon operation")
        print("Enter 2 to perform Deletion operation")
        print("Enter 3 to get Information about Set datatype")
        
       
        ch1=int(input("Enter your choice"))
        if ch1==1:
            print("You chose addition operation")
           
            print("Enter 1 to perform Add operation")
            print("Enter 2 to perform Update operation")
            ch2=int(input("Enter your choice of operation"))
            if ch2==1:
                print("You chose add operation")
                print("In Add operator we can add single value")
                a=eval(input("Enter values to be added in set"))
                s1.add(a)
                print("The outcome is",s1)
            elif ch2==2:
                print("You chose Update operator")
                print("In update operator we can add multiple values")
                a=eval(input("Enter values to be updated in set"))
                s1.update([a])
                print("The outcome is",s1)
            else:
                print("Invalid choice")
        elif ch1==2:
            print("You chose deletion operator")
            print("-"*100)
           
            print("Enter 1 to perform Pop operataion")
            print("Enter 2 to perform Remove operataion")
            print("Enter 3 to perform Discard operation")
            print("-"*100)
            ch2=int(input("Enter your choice of opertaion"))
            print("-"*100)
            if ch2==1:
                print("You chose pop operator")
                print("In pop any random value gets deleted")
                s1.pop()
                print("The outcome is",s1)
            elif ch2==2:
                print("you chose remove operator")
                print("In remove operator directly values gets removed")
                a=eval(input("Enter the value you wanted to be get removed"))
                s1.remove(a)
                print("The outcome is",s1)
            elif ch2==3:
                print("You chose Discard operator")
                print("This will remove values directly and it will not show the reeor if you chose values other than the set ")
                a=eval(input("Enter the values you wanted to be get removed"))
                s1.discard(a)
                print("The outcome is",s1)
            else:
                print("Invalid choice")
        elif ch1==3:
            print("Set is unordered heterogenous elements which are mutable")
        else:
            print("Wrong choice. Enter the choice again")
#Dictionary

elif ch==3:
    print("You chose dictionary datatype")
    print("-"*100)
    print("Create a dictionary")
    
    d1={}
    n=int(input("Enter the key-value pair number"))
    for i in range(n):
        
        k=eval(input("Enter key"))
        v=eval(input("Enter value"))
        d1.update({k:v})
    print(d1)

    print("Enter 1 to perform Addition operation")
    print("Enter 2 to perform Deletion operation")
    print("Enter 3 to get Definion of the Dictionary")
    
    ch3=int(input("Enter your choice"))
   
    if ch3==1:
        print("You chose Addition operator")
        
        
        
        
        print("Enter 1 for Adding values using keys")
        print("Enter 2 for Update method")
        print("\n")
        ch4=int(input("Enter your choice"))
        if ch4==1:
            print("In thid method we add single values in dictionary")
            print("\n")
            a=eval(input("Enter the name for key: "))
            b=eval(input("Enter the value of the key: "))
            d1[a]=b
            print("The outcome is",d1)
        elif ch4==2:
            print("In this method multiple values can be added to the dictionary")
            print("\n")
            n=int(input("Enter the no. of key-values pairs you wanted to be updated"))
            for i in range(n):
                
                a=input("Enter keys")
                b=input("Enter value")
                d1.update({a:b})
            print("The outcome is",d1)
        else:
            print("Enter valid choice")
    elif ch3==2:
        print("You chose Deletion operation")
        print("-"*100)
        print("Enter 1 for Delete method")
        print("Enter 2 for Pop method ")
        print("Enter 3 for Popitem method")
        print("Enter 4  for Clear method")
        ch4=int(input("Enter your choice"))
        if ch4==1:
            print("You chose Delete method")
            a=eval(input("Enter the value which you wanted to be deleted"))
            del d1[a]
            print("The outcome is",d1)
        elif ch4==2:
            print("You chose Pop method")
            a=eval(input("Enter value you wanted to be popped"))
            d1.pop(a)
            print("The outcome is",d1)
        elif ch4==3:
            print("You chose popitem method")
            d1.popitem()
            print("The outcome is",d1)
        elif ch4==4:
            print("You chose Clear method")
            d1.clear()
            print("This method clears the all values of the dictionary")
    elif ch3==3:
        print("The dictionary is unordered heterogeneous elements which are mutable and dynamic. But the keys should be unique and values can be duplicate")
    else:
        print(" wrong choice. Please enter your choice again")
        
#Tuple

elif ch==4:
    print("You chose Tuple datatype")
    print("-"*100)
    print("Create a Tuple")
    t1=tuple(eval(input("Enter the values")))
    print("-"*100)
    print("Tuple is Immutable. We cannot do Addition and Deletion operation in Tuple.")
    print("Enter 1 to get defination of Tuple")
    ch4=int(input("Enter your choice"))
    if ch4==1:
        print("Tuple is ordered heterogeneous elements which are immutable.")
    else:
        print("Enter valid chose")
# Out:
# Enter 1 for doing operation on the list
# Enter 2 for doing operation on the set
# Enter 3 for doing operation on the dictionary
# Enter 4 for doing operation on the tuple
# ----------------------------------------------------------------------------------------------------
# Enter your choice 3
# ----------------------------------------------------------------------------------------------------
# You chose dictionary datatype
# ----------------------------------------------------------------------------------------------------
# Create a dictionary
# Enter the key-value pair number2
# Enter key'amit'
# Enter value30
# Enter key'raj'
# Enter value9
# {'amit': 30, 'raj': 9}
# Enter 1 to perform Addition operation
# Enter 2 to perform Deletion operation
# Enter 3 to get Definion of the Dictionary
# Enter your choice2
# You chose Deletion operation
# ----------------------------------------------------------------------------------------------------
# Enter 1 for Delete method
# ...

# %% [markdown]
# #
